# %%
import googlemaps
import pandas as pd
import gmaps as gs

# %%
gmaps = googlemaps.Client(key='YOUR KEY HERE')
gs.configure(api_key='YOUR KEY HERE')

# %% [markdown]
# # TechPoint

# %%
techpoint = gmaps.geocode('1210 Waterway Blvd Suite 5000 Indianapolis, IN 46202')
techpoint_loc = techpoint[0]['geometry']['location']
techpoint_loc
# Out:
# {'lat': 39.7689853, 'lng': -86.1573476}

# %%
techpoint_marker = (techpoint_loc['lat'],techpoint_loc['lng'])
x = gs.figure(center=(techpoint_loc['lat'],techpoint_loc['lng']), zoom_level=12)
markers = gs.marker_layer([techpoint_marker])
x.add_layer(markers)
x
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# # Find A Place To Stay

# %%
hotel = gmaps.places_nearby(location=techpoint_loc, 
                             radius=2000,
                             keyword = 'hotel',
                             #rank_by='distance',
                             type='lodging')

hotels = pd.DataFrame(hotel['results'])

# %%
hotels.head()
# Out:
#    business_status                                           geometry  \
# 1      OPERATIONAL  {'location': {'lat': 39.7663443, 'lng': -86.16...
# 2      OPERATIONAL  {'location': {'lat': 39.7790868, 'lng': -86.14...
# 13     OPERATIONAL  {'location': {'lat': 39.7674572, 'lng': -86.15...
#
#                                                  icon icon_background_color  \
# 1   https://maps.gstatic.com/mapfiles/place_api/ic...               #909CE1
# 2   https://maps.gstatic.com/mapfiles/place_api/ic...               #909CE1
# 13  https://maps.gstatic.com/mapfiles/place_api/ic...               #909CE1
#
#                                    icon_mask_base_uri  \
# 1   https://maps.gstatic.com/mapfiles/place_api/ic...
# 2   https://maps.gstatic.com/mapfiles/place_api/ic...
# 13  https://maps.gstatic.com/mapfiles/place_api/ic...
#
#                         name  \
# 1   JW Marriott Indianapolis
# 2          Bottleworks Hotel
# 13       Conrad Indianapolis
#
#                                                photos  \
# 1   [{'height': 1366, 'html_attributions': ['<a hr...
# 2   [{'height': 3101, 'html_attributions': ['<a hr...
# 13  [{'height': 4016, 'html_attributions': ['<a hr...
#
#                        place_id  \
# 1   ChIJTUMHhbFQa4gRaoiyuJbUkNc
# 2   ChIJo1W3aFdRa4gRhe8tDkvErss
# 13  ChIJ7ykCbLxQa4gRRHXSCYSxNNs
#
#                                             plus_code  rating  \
# 1   {'compound_code': 'QR8J+GM Indianapolis, India...     4.5
# 2   {'compound_code': 'QVH4+JJ Indianapolis, India...     4.8
# 13  {'compound_code': 'QR8R+X7 Indianapolis, India...     4.6
#
#                       reference   scope  \
# 1   ChIJTUMHhbFQa4gRaoiyuJbUkNc  GOOGLE
# 2   ChIJo1W3aFdRa4gRhe8tDkvErss  GOOGLE
# 13  ChIJ7ykCbLxQa4gRRHXSCYSxNNs  GOOGLE
#
#                                           types  user_ratings_total  \
# 1   [lodging, point_of_interest, establishment]                6214
# 2   [lodging, point_of_interest, establishment]                 279
# 13  [lodging, point_of_interest, establishment]                1296
#
#                                          vicinity       opening_hours  \
# 1                      10 S West St, Indianapolis                 NaN
# 2   850 Massachusetts Ave Suite 100, Indianapolis  {'open_now': True}
# 13               50 W Washington St, Indianapolis                 NaN
#
#                                  geo
# 1          (39.7663443, -86.1683735)
# 2   (39.7790868, -86.14340349999999)
# 13         (39.7674572, -86.1593714)

# %%
#Visualize Hotels
hotels['geo'] = hotels.apply(lambda x: (x['geometry']['location']['lat'],x['geometry']['location']['lng']), axis=1)
hotel_layer = gs.symbol_layer(list(hotels['geo']), fill_color='yellow', 
                              stroke_color='yellow', scale=10,hover_text = list(hotels['name']) )
x.add_layer(hotel_layer)
x
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
hotels = hotels[hotels['rating']>4.4]
hotels
# Out:
#    business_status                                           geometry  \
# 1      OPERATIONAL  {'location': {'lat': 39.7663443, 'lng': -86.16...
# 2      OPERATIONAL  {'location': {'lat': 39.7790868, 'lng': -86.14...
# 13     OPERATIONAL  {'location': {'lat': 39.7674572, 'lng': -86.15...
#
#                                                  icon icon_background_color  \
# 1   https://maps.gstatic.com/mapfiles/place_api/ic...               #909CE1
# 2   https://maps.gstatic.com/mapfiles/place_api/ic...               #909CE1
# 13  https://maps.gstatic.com/mapfiles/place_api/ic...               #909CE1
#
#                                    icon_mask_base_uri  \
# 1   https://maps.gstatic.com/mapfiles/place_api/ic...
# 2   https://maps.gstatic.com/mapfiles/place_api/ic...
# 13  https://maps.gstatic.com/mapfiles/place_api/ic...
#
#                         name  \
# 1   JW Marriott Indianapolis
# 2          Bottleworks Hotel
# 13       Conrad Indianapolis
#
#                                                photos  \
# 1   [{'height': 1366, 'html_attributions': ['<a hr...
# 2   [{'height': 3101, 'html_attributions': ['<a hr...
# 13  [{'height': 4016, 'html_attributions': ['<a hr...
#
#                        place_id  \
# 1   ChIJTUMHhbFQa4gRaoiyuJbUkNc
# 2   ChIJo1W3aFdRa4gRhe8tDkvErss
# 13  ChIJ7ykCbLxQa4gRRHXSCYSxNNs
#
#                                             plus_code  rating  \
# 1   {'compound_code': 'QR8J+GM Indianapolis, India...     4.5
# 2   {'compound_code': 'QVH4+JJ Indianapolis, India...     4.8
# 13  {'compound_code': 'QR8R+X7 Indianapolis, India...     4.6
#
#                       reference   scope  \
# 1   ChIJTUMHhbFQa4gRaoiyuJbUkNc  GOOGLE
# 2   ChIJo1W3aFdRa4gRhe8tDkvErss  GOOGLE
# 13  ChIJ7ykCbLxQa4gRRHXSCYSxNNs  GOOGLE
#
#                                           types  user_ratings_total  \
# 1   [lodging, point_of_interest, establishment]                6214
# 2   [lodging, point_of_interest, establishment]                 279
# 13  [lodging, point_of_interest, establishment]                1296
#
#                                          vicinity       opening_hours  \
# 1                      10 S West St, Indianapolis                 NaN
# 2   850 Massachusetts Ave Suite 100, Indianapolis  {'open_now': True}
# 13               50 W Washington St, Indianapolis                 NaN
#
#                                  geo
# 1          (39.7663443, -86.1683735)
# 2   (39.7790868, -86.14340349999999)
# 13         (39.7674572, -86.1593714)

# %%
hotel_layer = gs.symbol_layer(list(hotels['geo']), fill_color='black', 
                              stroke_color='black', scale=10,hover_text = list(hotels['name']) )
x.add_layer(hotel_layer)
x
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# # Things To Do

# %%
uni = gmaps.places_nearby(location=techpoint_loc, 
                             radius=5000,
                             keyword = 'university',
                             #rank_by='distance',
                             type='university')
museum = gmaps.places_nearby(location=techpoint_loc, 
                             radius=5000,
                             type='museum')
restaurant = gmaps.places_nearby(location=techpoint_loc, 
                             radius=5000,
                             type='restaurant')

# %%
restaurant2 = gmaps.places_nearby(page_token = restaurant['next_page_token'])

# %%
unis = pd.DataFrame(uni['results'])
museums = pd.DataFrame(museum['results'])
restaurants = pd.DataFrame(restaurant['results']).append(pd.DataFrame(restaurant2['results']))
# Out:
# {'lat': 39.7689853, 'lng': -86.1573476}

# %%
restaurants.head()

# %% [markdown]
# ## Identifying location Data for All Destinations

# %%
unis['geo'] = unis.apply(lambda x: (x['geometry']['location']['lat'],x['geometry']['location']['lng']), axis=1)
museums['geo'] = museums.apply(lambda x: (x['geometry']['location']['lat'],x['geometry']['location']['lng']), axis=1)
restaurants['geo'] = restaurants.apply(lambda x: (x['geometry']['location']['lat'],x['geometry']['location']['lng']), axis=1)

# %% [markdown]
# ## Layer Markers in Google Maps

# %%
x = gs.figure(center=(techpoint_loc['lat'],techpoint_loc['lng']), zoom_level=12)
markers = gs.marker_layer([techpoint_marker])
x.add_layer(markers)

unis_layer = gs.symbol_layer(list(unis['geo']), fill_color='red', stroke_color='red', scale=10,hover_text = list(unis['name']) )
museums_layer = gs.symbol_layer(list(museums['geo']), fill_color='green', stroke_color='green', scale=10,hover_text = list(museums['name']) )
restaurants_layer = gs.symbol_layer(list(restaurants['geo']), fill_color='blue', stroke_color='blue', scale=10,hover_text = list(restaurants['name']) )

x.add_layer(unis_layer)
x.add_layer(museums_layer)
x.add_layer(restaurants_layer)
x
# Out:
#   business_status                                           geometry  \
# 0     OPERATIONAL  {'location': {'lat': 39.7653894, 'lng': -86.15...
# 1     OPERATIONAL  {'location': {'lat': 39.7663443, 'lng': -86.16...
# 2     OPERATIONAL  {'location': {'lat': 39.7790868, 'lng': -86.14...
# 3     OPERATIONAL  {'location': {'lat': 39.7689664, 'lng': -86.15...
# 4     OPERATIONAL  {'location': {'lat': 39.7686797, 'lng': -86.15...
#
#                                                 icon icon_background_color  \
# 0  https://maps.gstatic.com/mapfiles/place_api/ic...               #909CE1
# 1  https://maps.gstatic.com/mapfiles/place_api/ic...               #909CE1
# 2  https://maps.gstatic.com/mapfiles/place_api/ic...               #909CE1
# 3  https://maps.gstatic.com/mapfiles/place_api/ic...               #909CE1
# 4  https://maps.gstatic.com/mapfiles/place_api/ic...               #909CE1
#
#                                   icon_mask_base_uri  \
# 0  https://maps.gstatic.com/mapfiles/place_api/ic...
# 1  https://maps.gstatic.com/mapfiles/place_api/ic...
# 2  https://maps.gstatic.com/mapfiles/place_api/ic...
# 3  https://maps.gstatic.com/mapfiles/place_api/ic...
# 4  https://maps.gstatic.com/mapfiles/place_api/ic...
#
#                                                 name  \
# 0  Hampton Inn Indianapolis Downtown Across from ...
# 1                           JW Marriott Indianapolis
# 2                                  Bottleworks Hotel
# 3       Home2 Suites by Hilton Indianapolis Downtown
# 4            Hilton Garden Inn Indianapolis Downtown
#
#                                               photos  \
# 0  [{'height': 3000, 'html_attributions': ['<a hr...
# 1  [{'height': 1366, 'html_attributions': ['<a hr...
# 2  [{'height': 3101, 'html_attributions': ['<a hr...
# 3  [{'height': 3000, 'html_attributions': ['<a hr...
# 4  [{'height': 3500, 'html_attributions': ['<a hr...
#
#                       place_id  \
# 0  ChIJFZV977xQa4gRVj6rqo5e1hc
# 1  ChIJTUMHhbFQa4gRaoiyuJbUkNc
# 2  ChIJo1W3aFdRa4gRhe8tDkvErss
# 3  ChIJVxiaC75Qa4gRSMEofkel6Cs
# 4  ChIJGWFY2L1Qa4gRZgzfcxIq4EM
#
#                                            plus_code  rating  \
# 0  {'compound_code': 'QR8R+5W Indianapolis, India...     4.2
# 1  {'compound_code': 'QR8J+GM Indianapolis, India...     4.5
# 2  {'compound_code': 'QVH4+JJ Indianapolis, India...     4.8
# 3  {'compound_code': 'QR9V+HJ Indianapolis, India...     4.4
# 4  {'compound_code': 'QR9V+F9 Indianapolis, India...     4.3
#
#                      reference   scope  \
# 0  ChIJFZV977xQa4gRVj6rqo5e1hc  GOOGLE
# 1  ChIJTUMHhbFQa4gRaoiyuJbUkNc  GOOGLE
# 2  ChIJo1W3aFdRa4gRhe8tDkvErss  GOOGLE
# 3  ChIJVxiaC75Qa4gRSMEofkel6Cs  GOOGLE
# 4  ChIJGWFY2L1Qa4gRZgzfcxIq4EM  GOOGLE
#
#                                          types  user_ratings_total  \
# 0  [lodging, point_of_interest, establishment]                1400
# 1  [lodging, point_of_interest, establishment]                6212
# 2  [lodging, point_of_interest, establishment]                 279
# 3  [lodging, point_of_interest, establishment]                 896
# 4  [lodging, point_of_interest, establishment]                1481
#
#                                         vicinity       opening_hours
# 0                105 S Meridian St, Indianapolis                 NaN
# 1                     10 S West St, Indianapolis                 NaN
# 2  850 Massachusetts Ave Suite 100, Indianapolis  {'open_now': True}
# 3    115 N Pennsylvania St Ste 150, Indianapolis                 NaN
# 4                   10 E Market St, Indianapolis                 NaN

# %%
# Out:
#   business_status                                           geometry  \
# 0     OPERATIONAL  {'location': {'lat': 39.756264, 'lng': -86.159...
# 1     OPERATIONAL  {'location': {'lat': 39.7736134, 'lng': -86.15...
# 2     OPERATIONAL  {'location': {'lat': 39.76484749999999, 'lng':...
# 3     OPERATIONAL  {'location': {'lat': 39.764575, 'lng': -86.159...
# 4     OPERATIONAL  {'location': {'lat': 39.76794799999999, 'lng':...
#
#                                                 icon icon_background_color  \
# 0  https://maps.gstatic.com/mapfiles/place_api/ic...               #4B96F3
# 1  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 2  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 3  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 4  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
#
#                                   icon_mask_base_uri  \
# 0  https://maps.gstatic.com/mapfiles/place_api/ic...
# 1  https://maps.gstatic.com/mapfiles/place_api/ic...
# 2  https://maps.gstatic.com/mapfiles/place_api/ic...
# 3  https://maps.gstatic.com/mapfiles/place_api/ic...
# 4  https://maps.gstatic.com/mapfiles/place_api/ic...
#
#                                name       opening_hours  \
# 0            Shapiro's Delicatessen  {'open_now': True}
# 1                   The Rathskeller  {'open_now': True}
# 2              St. Elmo Steak House  {'open_now': True}
# 3                    Harry & Izzy's  {'open_now': True}
# 4  Buca di Beppo Italian Restaurant  {'open_now': True}
#
#                                               photos  \
# 0  [{'height': 6656, 'html_attributions': ['<a hr...
# 1  [{'height': 3279, 'html_attributions': ['<a hr...
# 2  [{'height': 3072, 'html_attributions': ['<a hr...
# 3  [{'height': 722, 'html_attributions': ['<a hre...
# 4  [{'height': 3000, 'html_attributions': ['<a hr...
#
#                       place_id  \
# 0  ChIJv0dTL6FQa4gRa7_BqZFb5bo
# 1  ChIJu8tmVOtQa4gRMXEfW9DtZ-k
# 2  ChIJL-H0oLxQa4gRtk7Der5Av0w
# 3  ChIJc5jIp7xQa4gRyBw22V5K24k
# 4  ChIJfSZuCbxQa4gRr1KhsSLC9y0
#
#                                            plus_code  price_level  rating  \
# 0  {'compound_code': 'QR4R+G5 Indianapolis, IN, U...          2.0     4.5
# 1  {'compound_code': 'QRFX+CW Indianapolis, IN, U...          2.0     4.5
# 2  {'compound_code': 'QR7R+W3 Indianapolis, IN, U...          4.0     4.7
# 3  {'compound_code': 'QR7R+R4 Indianapolis, IN, U...          4.0     4.7
# 4  {'compound_code': 'QR9R+54 Indianapolis, IN, U...          2.0     4.1
#
#                      reference   scope  \
# 0  ChIJv0dTL6FQa4gRa7_BqZFb5bo  GOOGLE
# 1  ChIJu8tmVOtQa4gRMXEfW9DtZ-k  GOOGLE
# 2  ChIJL-H0oLxQa4gRtk7Der5Av0w  GOOGLE
# 3  ChIJc5jIp7xQa4gRyBw22V5K24k  GOOGLE
# 4  ChIJfSZuCbxQa4gRr1KhsSLC9y0  GOOGLE
#
#                                                types  user_ratings_total  \
# 0  [meal_takeaway, bakery, restaurant, food, stor...                4991
# 1  [bar, restaurant, food, point_of_interest, est...                3059
# 2  [night_club, bar, restaurant, food, point_of_i...                4133
# 3  [restaurant, food, point_of_interest, establis...                2962
# 4  [restaurant, food, point_of_interest, establis...                2187
#
#                                   vicinity
# 0  808 South Meridian Street, Indianapolis
# 1   401 East Michigan Street, Indianapolis
# 2  127 South Illinois Street, Indianapolis
# 3  153 South Illinois Street, Indianapolis
# 4   35 North Illinois Street, Indianapolis

# %%
# Out:
# 1

# %%
# Out:
#   business_status                                           geometry  \
# 0     OPERATIONAL  {'location': {'lat': 39.7790868, 'lng': -86.14...
#
#                                                 icon icon_background_color  \
# 0  https://maps.gstatic.com/mapfiles/place_api/ic...               #909CE1
#
#                                   icon_mask_base_uri               name  \
# 0  https://maps.gstatic.com/mapfiles/place_api/ic...  Bottleworks Hotel
#
#         opening_hours                                             photos  \
# 0  {'open_now': True}  [{'height': 3101, 'html_attributions': ['<a hr...
#
#                       place_id  \
# 0  ChIJo1W3aFdRa4gRhe8tDkvErss
#
#                                            plus_code  rating  \
# 0  {'compound_code': 'QVH4+JJ Indianapolis, India...     4.8
#
#                      reference   scope  \
# 0  ChIJo1W3aFdRa4gRhe8tDkvErss  GOOGLE
#
#                                          types  user_ratings_total  \
# 0  [lodging, point_of_interest, establishment]                 279
#
#                                         vicinity  \
# 0  850 Massachusetts Ave Suite 100, Indianapolis
#
#                                 geo
# 0  (39.7790868, -86.14340349999999)

# %%
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Out:
# [(39.8101434, -86.2090864),
#  (39.7749927, -86.1772798),
#  (39.7797659, -86.1752156),
#  (39.7772085, -86.16348819999999),
#  (39.7666101, -86.1593462),
#  (39.79822009999999, -86.1039404),
#  (39.7710665, -86.17548939999999),
#  (39.772707, -86.14376650000001),
#  (39.77485660000001, -86.16536860000001),
#  (39.81410899999999, -86.2030827),
#  (39.7696979, -86.16022579999999),
#  (39.77661190000001, -86.1782753),
#  (39.81549620000001, -86.2024675),
#  (39.772955, -86.17215589999999),
#  (39.7696388, -86.1602801),
#  (39.8108805, -86.202795),
#  (39.7731728, -86.1821113),
#  (39.81360859999999, -86.2035322),
#  (39.7769471, -86.16847779999999),
#  (39.8053887, -86.158936)]

# %%
# Out:
# Figure(layout=FigureLayout(height='420px'))
